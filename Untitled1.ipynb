# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('movies_metadata.csv')

vote_average = df['vote_average']
original_title = df['original_title']

plt.hist(vote_average, bins=10, edgecolor='black')
plt.xlabel('Vote Average')
plt.ylabel('Frequency')
plt.title('Distribution of Vote Average in Movies')
plt.xticks(range(11))
plt.grid(True)

plt.show()
# Out:
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\851754471.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_metadata.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('movies_metadata.csv')

# Select the relevant columns and sort by 'vote_average' in descending order
top_10_movies = data[['original_title', 'vote_average', 'popularity']].sort_values('vote_average', ascending=False).head(10)

# Create the double line graph
plt.figure(figsize=(12, 6))

# Plot the 'vote_average' line
plt.plot(top_10_movies['original_title'], top_10_movies['vote_average'], marker='o', label='Vote Average')

# Plot the 'popularity' line
plt.plot(top_10_movies['original_title'], top_10_movies['popularity'], marker='o', label='Popularity')

# Set the labels and title
plt.xlabel('Movies')
plt.ylabel('Score')
plt.title('Top 10 Movies - Vote Average vs. Popularity')
plt.xticks(rotation=90)

# Add a legend
plt.legend()

# Display the graph
plt.show()
# Out:
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\81085193.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('movies_metadata.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('movies_metadata.csv')

# Sort the dataset based on 'vote_average' column in descending order
sorted_df = df.sort_values('vote_average', ascending=False)

# Select the top 10 movies
top_10_movies = sorted_df.head(10)

# Extract the 'original_title' and 'vote_average' columns
titles = top_10_movies['original_title']
votes = top_10_movies['vote_average']

# Create the line graph
plt.plot(titles, votes, marker='o')
plt.xlabel('Movie Title')
plt.ylabel('Vote Average')
plt.title('Top 10 Movies by Vote Average')
plt.xticks(rotation=90)
plt.tight_layout()

# Display the graph
plt.show()
# Out:
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\2535806602.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_metadata.csv')
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\2535806602.py:23: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('movies_metadata.csv')

# Extract the relevant columns
df = data[['vote_average', 'original_title']]

# Sort the dataframe by 'vote_average' in ascending order
df = df.sort_values('vote_average')

# Plot the line graph
plt.plot(df['original_title'], df['vote_average'])
plt.xlabel('Movie Title')
plt.ylabel('Vote Average')
plt.xticks(rotation=90)
plt.title('Vote Average for Movies')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\2999893207.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('movies_metadata.csv')
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\2999893207.py:19: UserWarning: Glyph 38525 (\N{CJK UNIFIED IDEOGRAPH-967D}) missing from current font.
#   plt.tight_layout()
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\2999893207.py:19: UserWarning: Glyph 12399 (\N{HIRAGANA LETTER HA}) missing from current font.
#   plt.tight_layout()
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\2999893207.py:19: UserWarning: Glyph 20670 (\N{CJK UNIFIED IDEOGRAPH-50BE}) missing from current font.
#   plt.tight_layout()
# C:\Users\SUVANSH\AppData\Local\Temp\ipykernel_15136\2999893207.py:19: UserWarning: Glyph 12406 (\N{HIRAGANA LETTER BU}) missing from current font.
#   plt.tight_layout()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset, specifying the data types and setting low_memory=False
data = pd.read_csv('movies_metadata.csv', dtype={'vote_average': float, 'original_title': str}, low_memory=False)

# Extract the relevant columns
df = data[['vote_average', 'original_title']]

# Sort the dataframe by 'vote_average' in ascending order
df = df.sort_values('vote_average')

# Plot the line graph
plt.plot(df['original_title'], df['vote_average'])
plt.xlabel('Movie Title')
plt.ylabel('Vote Average')
plt.xticks(rotation=90)
plt.title('Vote Average for Movies')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the movie dataset, specifying the data type for the "overview" column

movies_df = pd.read_csv("movies_metadata.csv", dtype={"overview": str}, low_memory=False)


# Create a TfidfVectorizer object with stop words

tfidf_vectorizer = TfidfVectorizer(stop_words='english')


# Preprocess the movie descriptions

movies_df["overview"] = movies_df["overview"].fillna("")  # Handling missing values

# Fit the TF-IDF vectorizer with the movie overviews
tfidf_matrix = tfidf_vectorizer.fit_transform(movies_df["overview"])

def get_recommendations(movie_title):
    # Search for the movie using the "original_title" column
    movie_indices = movies_df[movies_df["original_title"] == movie_title].index

    if len(movie_indices) == 0:
        print("Movie not found.")
        return []

    movie_index = movie_indices[0]

    # Preprocess the movie title
    processed_title = tfidf_vectorizer.transform([movie_title])

    # Get the cosine similarities for the movie title
    cosine_similarities = cosine_similarity(processed_title, tfidf_matrix).flatten()

    # Get the indices of top similar movies
    top_similar_movies = np.argsort(cosine_similarities)[::-1]

    # Get the top 10 movie recommendations (excluding the movie itself)
    recommendations = []
    for movie in top_similar_movies:
        if movie != movie_index:  # Skip the current movie index
            recommendations.append(movies_df.loc[movie, "original_title"])
            if len(recommendations) == 10:  # Limit the number of recommendations to 10
                break

    return recommendations

# Example usage:
# Get the movie recommendations for "Lucy"
recommendations = get_recommendations("Lucy")

# Print the movie recommendations
for movie in recommendations:
    print(movie)
